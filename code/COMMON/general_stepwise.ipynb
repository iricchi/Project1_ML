# %% [markdown]
# # Test step wise

# %%
# TO RUN IT: CHANGE MY PATH

import sys
my_path = r'/home/ilaria/Scrivania/Machine_Learning/Project_1/Project1_ML'
sys.path.insert(0,my_path + r'/code/COMMON')

import numpy as np 
import matplotlib.pyplot as plt
from proj1_helpers import load_csv_data, predict_labels 
from implementations import *
from outliers import handle_outliers
from labels import idx_2labels
from standard import standardize
from costs import *
from optimize_hyperparams import *
from cross_validation import *
from step_wise import *

# %% [markdown]
# ## Import data and standardization

# %%
yb, input_data, ids = load_csv_data(my_path + r'/data/train.csv', sub_sample=False)

# %%
input_data, Y = handle_outliers(input_data,yb,-999,'mean') # substiution with mean because the standardization
                                                           #can be affected, otherwise we should delete the whole row
ind_back, ind_sig = idx_2labels(Y, [-1,1])
Y[ind_back] = 0

input_data, mean_X, std_X = standardize(input_data)
# Out:
# -999 are replaced by the mean value of the feature

# %% [markdown]
# ## Pick the candidates for the regression

# %%
all_candidates = input_data

# all_candidates = np.concatenate(all_candidates, np.log(all_candidates[:,7]).reshape(len(all_candidates),1))

# %% [markdown]
# ### Set the features to select

# %%
all_features = np.genfromtxt(my_path + r'/data/train.csv', delimiter=",", dtype=str, max_rows = 1)[2:]

# converting array in list in order to simplify the adding of features
all_features = list(all_features)

# APPEND OTHER FEATURES
# all_features.append()   #different combination

features = []
for i in range(len(all_features)):
    features.append((i,all_features[i]))

# %% [markdown]
# # Set the dictionary for the model and the parameters

# %%
model = dict()
model['method'] = 'lr'

# for logistic regression
#model['max_iters'] = , model['gamma'] = , model['method_minimization'] = 'gd' 

R2_method = 'McFadden'  # R2 error = 'loss', R2 Tjur = 'Tjur', R2 McFadden = 'McFadden'

cv = 0  # 0 = no crossvalidation , 1 = yes


#############################################################################################
#set the dictionary for the args of cross validation:  SUBSTITUDE ARG WITH MODEL

### logistic regression

model['loss'] = 'loglikelihood'
model['degree'] = 3
model['k_fold'] = 5
model['max_iters'] = 50
#model['initial_w'] = np.ones(all_candidates.shape[1])   NO 
model['method_minimization'] = 'gd' # 'gd' (gradient_descent) or 'newton'
model['gamma'] = 1e-5
################################################################################################

# %%
best_R2adj, idx_features = stepwise(model, R2_method, all_candidates, features, Y, cv)
# Out:
# Logistic Regression (23/50): loss logLikelihood=160697.32656892634
# Logistic Regression (24/50): loss logLikelihood=160686.30282963745
# Logistic Regression (50/50): loss logLikelihood=142406.7558479375
# Logistic Regression (25/50): loss logLikelihood=160672.31092226168
# Logistic Regression (27/50): loss logLikelihood=156169.38374789484
# Logistic Regression (29/50): loss logLikelihood=156481.92033644443
# Logistic Regression (42/50): loss logLikelihood=156726.62790975627
# Logistic Regression (35/50): loss logLikelihood=157189.48688856748
# Logistic Regression (23/50): loss logLikelihood=160678.57030224806
# Logistic Regression (27/50): loss logLikelihood=160666.87458428316
# Logistic Regression (24/50): loss logLikelihood=157852.72952035986
# Logistic Regression (50/50): loss logLikelihood=154956.92710751024
# Logistic Regression (32/50): loss logLikelihood=151363.21898291624
# Logistic Regression (25/50): loss logLikelihood=156921.1508947206
# Logistic Regression (38/50): loss logLikelihood=153578.56866680278
# Logistic Regression (24/50): loss logLikelihood=160697.2153531539
# Logistic Regression (24/50): loss logLikelihood=160694.90372671402
# Logistic Regression (27/50): loss logLikelihood=160566.26860256324
# Logistic Regression (24/50): loss logLikelihood=160697.0391995455
# Logistic Regression (24/50): loss logLikelihood=160695.19905314187
# Logistic Regression (24/50): loss logLikelihood=160634.7961407044
# Logistic Regression (24/50): loss logLikelihood=160690.34143311792
# Logistic Regression (23/50): loss logLikelihood=158460.59469420015
# Logistic Regression (25/50): loss logLikelihood=158491.13280058876
# Logistic Regression (23/50): loss logLikelihood=160371.10277154166
# Logistic Regression (24/50): loss logLikelihood=160697.3084935244
# Logistic Regression (24/50): loss logLikelihood=160697.32051231823
# Logistic Regression (26/50): loss logLikelihood=160673.56264505463
# Logistic Regression (24/50): loss logLikelihood=160697.2574149533
# Logistic Regression (24/50): loss logLikelihood=160695.9301476131
# Logistic Regression (23/50): loss logLikelihood=158512.19836222412
# -------------------------------------------------
# Feature chosen:  PRI_tau_pt (index : 13 )
# Logistic Regression (45/50): loss logLikelihood=153167.3497331965
# Logistic Regression (50/50): loss logLikelihood=138184.2846477048
# Logistic Regression (50/50): loss logLikelihood=152430.68880248166
# Logistic Regression (48/50): loss logLikelihood=152118.37219113146
# Logistic Regression (41/50): loss logLikelihood=149302.33000562395
# Logistic Regression (48/50): loss logLikelihood=150112.912727524
# Logistic Regression (39/50): loss logLikelihood=150213.45656013797
# Logistic Regression (45/50): loss logLikelihood=153037.92080387243
# Logistic Regression (39/50): loss logLikelihood=153366.29904967084
# Logistic Regression (50/50): loss logLikelihood=153329.4005547068
# Logistic Regression (50/50): loss logLikelihood=152364.30361428607
# Logistic Regression (40/50): loss logLikelihood=146023.24481157612
# Logistic Regression (41/50): loss logLikelihood=149895.97621009962
# Logistic Regression (38/50): loss logLikelihood=153578.56167536255
# Logistic Regression (38/50): loss logLikelihood=153575.79753326104
# Logistic Regression (40/50): loss logLikelihood=153137.72476498055
# Logistic Regression (38/50): loss logLikelihood=153578.24358516204
# Logistic Regression (38/50): loss logLikelihood=153577.00057809032
# Logistic Regression (40/50): loss logLikelihood=153526.2791815156
# Logistic Regression (38/50): loss logLikelihood=153572.63994960344
# Logistic Regression (50/50): loss logLikelihood=153439.0807405535
# Logistic Regression (41/50): loss logLikelihood=152655.11471023434
# Logistic Regression (42/50): loss logLikelihood=153559.4262556573
# Logistic Regression (38/50): loss logLikelihood=153578.56453853735
# Logistic Regression (38/50): loss logLikelihood=153578.39568149878
# Logistic Regression (39/50): loss logLikelihood=153381.30882987622
# Logistic Regression (39/50): loss logLikelihood=153578.46181822786
# Logistic Regression (39/50): loss logLikelihood=153577.93533004232
# Logistic Regression (44/50): loss logLikelihood=153095.38875333944
# -------------------------------------------------
# Feature chosen:  DER_mass_jet_jet (index : 5 )
# Logistic Regression (50/50): loss logLikelihood=149747.11146256124
# Logistic Regression (50/50): loss logLikelihood=135356.0023997961
# Logistic Regression (50/50): loss logLikelihood=149120.91398997855
# Logistic Regression (50/50): loss logLikelihood=148969.7773543016
# Logistic Regression (50/50): loss logLikelihood=149209.69522357814
# Logistic Regression (50/50): loss logLikelihood=149771.20958377342
# Logistic Regression (50/50): loss logLikelihood=149422.71564607768
# Logistic Regression (49/50): loss logLikelihood=149949.27737568872
# Logistic Regression (50/50): loss logLikelihood=150029.67912459053
# Logistic Regression (50/50): loss logLikelihood=148808.48083111725
# Logistic Regression (50/50): loss logLikelihood=142988.6351358359
# Logistic Regression (50/50): loss logLikelihood=148727.52500665255
# Logistic Regression (48/50): loss logLikelihood=150112.90916580922
# Logistic Regression (48/50): loss logLikelihood=150109.95444868848
# Logistic Regression (49/50): loss logLikelihood=149612.36474043588
# Logistic Regression (48/50): loss logLikelihood=150112.4348055925
# Logistic Regression (48/50): loss logLikelihood=150110.9990271119
# Logistic Regression (50/50): loss logLikelihood=149959.211721217
# Logistic Regression (48/50): loss logLikelihood=150106.85185500814
# Logistic Regression (50/50): loss logLikelihood=150052.22437682629
# Logistic Regression (50/50): loss logLikelihood=149003.8620155355
# Logistic Regression (50/50): loss logLikelihood=149829.55400803173
# Logistic Regression (48/50): loss logLikelihood=150112.91102436077
# Logistic Regression (48/50): loss logLikelihood=150112.68493053515
# Logistic Regression (50/50): loss logLikelihood=149217.65088964684
# Logistic Regression (49/50): loss logLikelihood=150112.54488013507
# Logistic Regression (49/50): loss logLikelihood=150112.30353136393
# Logistic Regression (50/50): loss logLikelihood=149885.00080591952
# -------------------------------------------------
# Feature chosen:  DER_mass_transverse_met_lep (index : 1 )
# Logistic Regression (50/50): loss logLikelihood=135304.53218205192
# Logistic Regression (50/50): loss logLikelihood=135344.15406951337
# Logistic Regression (50/50): loss logLikelihood=135326.31746068443
# Logistic Regression (50/50): loss logLikelihood=134685.02048585314
# Logistic Regression (50/50): loss logLikelihood=135117.59755767504
# Logistic Regression (50/50): loss logLikelihood=134458.5830194929
# Logistic Regression (50/50): loss logLikelihood=135178.1587373099
# Logistic Regression (50/50): loss logLikelihood=135315.59801641662
# Logistic Regression (50/50): loss logLikelihood=135334.92224653214
# Logistic Regression (50/50): loss logLikelihood=134005.23273986293
# Logistic Regression (50/50): loss logLikelihood=134203.4578807963
# Logistic Regression (50/50): loss logLikelihood=135355.84040773183
# Logistic Regression (50/50): loss logLikelihood=135353.51939907274
# Logistic Regression (50/50): loss logLikelihood=135247.5807163897
# Logistic Regression (50/50): loss logLikelihood=135355.87691478428
# Logistic Regression (50/50): loss logLikelihood=135353.77898475906
# Logistic Regression (50/50): loss logLikelihood=135305.29507287173
# Logistic Regression (50/50): loss logLikelihood=135355.8228432346
# Logistic Regression (50/50): loss logLikelihood=135248.87228530465
# Logistic Regression (50/50): loss logLikelihood=135296.84255920813
# Logistic Regression (50/50): loss logLikelihood=134953.04710688096
# Logistic Regression (50/50): loss logLikelihood=135355.99621532633
# Logistic Regression (50/50): loss logLikelihood=135355.93036103543
# Logistic Regression (50/50): loss logLikelihood=134461.58751448954
# Logistic Regression (50/50): loss logLikelihood=135355.62095147575
# Logistic Regression (50/50): loss logLikelihood=135355.81940576408
# Logistic Regression (50/50): loss logLikelihood=135270.64757064395
# -------------------------------------------------
# Feature chosen:  DER_lep_eta_centrality (index : 12 )
# Logistic Regression (50/50): loss logLikelihood=134151.1865444465
# Logistic Regression (50/50): loss logLikelihood=134191.50416368875
# Logistic Regression (50/50): loss logLikelihood=134156.32092474544
# Logistic Regression (50/50): loss logLikelihood=134079.66564335572
# Logistic Regression (50/50): loss logLikelihood=134184.5890790985
# Logistic Regression (50/50): loss logLikelihood=133333.21623090774
# Logistic Regression (50/50): loss logLikelihood=134090.29545898997
# Logistic Regression (50/50): loss logLikelihood=134190.53847049427
# Logistic Regression (50/50): loss logLikelihood=134187.22083169746
# Logistic Regression (50/50): loss logLikelihood=132904.79593651832
# Logistic Regression (50/50): loss logLikelihood=134203.2677299574
# Logistic Regression (50/50): loss logLikelihood=134201.2060582011
# Logistic Regression (50/50): loss logLikelihood=134080.9991461887
# Logistic Regression (50/50): loss logLikelihood=134203.3152379631
# Logistic Regression (50/50): loss logLikelihood=134201.43815182024
# Logistic Regression (50/50): loss logLikelihood=134127.14376080036
# Logistic Regression (50/50): loss logLikelihood=134203.30736780755
# Logistic Regression (50/50): loss logLikelihood=134145.57947410524
# Logistic Regression (50/50): loss logLikelihood=134157.77758631014
# Logistic Regression (50/50): loss logLikelihood=133955.2323173425
# Logistic Regression (50/50): loss logLikelihood=134203.4492828783
# Logistic Regression (50/50): loss logLikelihood=134203.35765881877
# Logistic Regression (50/50): loss logLikelihood=133633.65524188438
# Logistic Regression (50/50): loss logLikelihood=134203.27497854488
# Logistic Regression (50/50): loss logLikelihood=134203.29644440155
# Logistic Regression (50/50): loss logLikelihood=134163.04152485883
# -------------------------------------------------
# Feature chosen:  DER_met_phi_centrality (index : 11 )
# Logistic Regression (50/50): loss logLikelihood=132878.58909538348
# Logistic Regression (50/50): loss logLikelihood=132904.4954065487
# Logistic Regression (50/50): loss logLikelihood=132744.468945818
# Logistic Regression (50/50): loss logLikelihood=132771.83993254308
# Logistic Regression (50/50): loss logLikelihood=132885.4381564654
# Logistic Regression (50/50): loss logLikelihood=131307.80547234297
# Logistic Regression (50/50): loss logLikelihood=132570.9124393226
# Logistic Regression (50/50): loss logLikelihood=132525.76419067362
# Logistic Regression (50/50): loss logLikelihood=132797.641120802
# Logistic Regression (50/50): loss logLikelihood=132904.416547797
# Logistic Regression (50/50): loss logLikelihood=132902.5269241622
# Logistic Regression (50/50): loss logLikelihood=132880.0840945344
# Logistic Regression (50/50): loss logLikelihood=132904.34638918535
# Logistic Regression (50/50): loss logLikelihood=132902.75214740445
# Logistic Regression (50/50): loss logLikelihood=132903.23925076638
# Logistic Regression (50/50): loss logLikelihood=132904.70370363322
# Logistic Regression (50/50): loss logLikelihood=132351.54016382387
# Logistic Regression (50/50): loss logLikelihood=132802.85102422966
# Logistic Regression (50/50): loss logLikelihood=132634.41162704493
# Logistic Regression (50/50): loss logLikelihood=132904.7380494972
# Logistic Regression (50/50): loss logLikelihood=132904.72284735285
# Logistic Regression (50/50): loss logLikelihood=132292.15935332284
# Logistic Regression (50/50): loss logLikelihood=132904.5384881072
# Logistic Regression (50/50): loss logLikelihood=132904.75948620998
# Logistic Regression (50/50): loss logLikelihood=132394.4410257677
# -------------------------------------------------
# Feature chosen:  DER_deltar_tau_lep (index : 7 )
# Logistic Regression (50/50): loss logLikelihood=130817.2007366791
# Logistic Regression (50/50): loss logLikelihood=129825.0766754524
# Logistic Regression (50/50): loss logLikelihood=131145.39168623253
# Logistic Regression (50/50): loss logLikelihood=131249.8633963425
# Logistic Regression (50/50): loss logLikelihood=131302.4792997559
# Logistic Regression (50/50): loss logLikelihood=131127.26665376272
# Logistic Regression (50/50): loss logLikelihood=131300.7171825044
# Logistic Regression (50/50): loss logLikelihood=131262.9069853966
# Logistic Regression (50/50): loss logLikelihood=131307.2379329779
# Logistic Regression (50/50): loss logLikelihood=131306.59945451198
# Logistic Regression (50/50): loss logLikelihood=131231.0392661169
# Logistic Regression (50/50): loss logLikelihood=131307.2125271657
# Logistic Regression (50/50): loss logLikelihood=131305.74578042232
# Logistic Regression (50/50): loss logLikelihood=131047.64846201734
# Logistic Regression (50/50): loss logLikelihood=131307.69611137296
# Logistic Regression (50/50): loss logLikelihood=131231.37458235337
# Logistic Regression (50/50): loss logLikelihood=131295.01044575305
# Logistic Regression (50/50): loss logLikelihood=131284.02989151064
# Logistic Regression (50/50): loss logLikelihood=131307.70992835923
# Logistic Regression (50/50): loss logLikelihood=131307.80538859687
# Logistic Regression (50/50): loss logLikelihood=130890.91425534365
# Logistic Regression (50/50): loss logLikelihood=131307.53889484174
# Logistic Regression (50/50): loss logLikelihood=131307.7285187727
# Logistic Regression (50/50): loss logLikelihood=131280.41293193673
# -------------------------------------------------
# Feature chosen:  DER_mass_vis (index : 2 )
# Logistic Regression (50/50): loss logLikelihood=129746.71077778877
# Logistic Regression (50/50): loss logLikelihood=128982.7437489761
# Logistic Regression (50/50): loss logLikelihood=129782.9752501301
# Logistic Regression (50/50): loss logLikelihood=129822.70468373134
# Logistic Regression (50/50): loss logLikelihood=129695.96089963696
# Logistic Regression (50/50): loss logLikelihood=129679.33268086989
# Logistic Regression (50/50): loss logLikelihood=129682.56059555794
# Logistic Regression (50/50): loss logLikelihood=129824.43705949248
# Logistic Regression (50/50): loss logLikelihood=129824.3598795054
# Logistic Regression (50/50): loss logLikelihood=128332.28551376692
# Logistic Regression (50/50): loss logLikelihood=129824.67572965437
# Logistic Regression (50/50): loss logLikelihood=129823.62143003904
# Logistic Regression (50/50): loss logLikelihood=129421.36661534586
# Logistic Regression (50/50): loss logLikelihood=129824.89818579423
# Logistic Regression (50/50): loss logLikelihood=129821.22648338228
# Logistic Regression (50/50): loss logLikelihood=129661.96289694184
# Logistic Regression (50/50): loss logLikelihood=129821.94630262756
# Logistic Regression (50/50): loss logLikelihood=129825.03486785833
# Logistic Regression (50/50): loss logLikelihood=129825.06452889385
# Logistic Regression (50/50): loss logLikelihood=129431.36942648795
# Logistic Regression (50/50): loss logLikelihood=129824.73180939232
# Logistic Regression (50/50): loss logLikelihood=129824.93964866464
# Logistic Regression (50/50): loss logLikelihood=129803.9289730009
# -------------------------------------------------
# Feature chosen:  PRI_met (index : 19 )
# Logistic Regression (50/50): loss logLikelihood=129423.18023127812
# Logistic Regression (50/50): loss logLikelihood=128976.10100677858
# Logistic Regression (50/50): loss logLikelihood=129329.36491066783
# Logistic Regression (50/50): loss logLikelihood=129409.60827037861
# Logistic Regression (50/50): loss logLikelihood=129203.46713990689
# Logistic Regression (50/50): loss logLikelihood=129407.20960741203
# Logistic Regression (50/50): loss logLikelihood=129294.4411857587
# Logistic Regression (50/50): loss logLikelihood=129420.66564845147
# Logistic Regression (50/50): loss logLikelihood=129420.54857545973
# Logistic Regression (50/50): loss logLikelihood=127939.14196335568
# Logistic Regression (50/50): loss logLikelihood=129420.96854653109
# Logistic Regression (50/50): loss logLikelihood=129419.72949144238
# Logistic Regression (50/50): loss logLikelihood=129421.22217540337
# Logistic Regression (50/50): loss logLikelihood=129381.38267837926
# Logistic Regression (50/50): loss logLikelihood=129345.43446311796
# Logistic Regression (50/50): loss logLikelihood=129285.5296990478
# Logistic Regression (50/50): loss logLikelihood=129421.33339008299
# Logistic Regression (50/50): loss logLikelihood=129421.32888997307
# Logistic Regression (50/50): loss logLikelihood=128872.51789563322
# Logistic Regression (50/50): loss logLikelihood=129421.11486268177
# Logistic Regression (50/50): loss logLikelihood=129421.18045235642
# Logistic Regression (50/50): loss logLikelihood=129394.02321534802
# -------------------------------------------------
# Feature chosen:  PRI_jet_subleading_pt (index : 26 )
# Logistic Regression (50/50): loss logLikelihood=128875.81590464739
# Logistic Regression (50/50): loss logLikelihood=128305.51734697983
# Logistic Regression (50/50): loss logLikelihood=128869.20196808853
# Logistic Regression (50/50): loss logLikelihood=128868.48511051775
# Logistic Regression (50/50): loss logLikelihood=128761.93520907231
# Logistic Regression (50/50): loss logLikelihood=128597.33442659742
# Logistic Regression (50/50): loss logLikelihood=128701.4548191536
# Logistic Regression (50/50): loss logLikelihood=128871.78197860776
# Logistic Regression (50/50): loss logLikelihood=128871.73858224439
# Logistic Regression (50/50): loss logLikelihood=127176.49633587111
# Logistic Regression (50/50): loss logLikelihood=128872.07889119117
# Logistic Regression (50/50): loss logLikelihood=128870.90801740858
# Logistic Regression (50/50): loss logLikelihood=128872.36059707419
# Logistic Regression (50/50): loss logLikelihood=128864.85220158375
# Logistic Regression (50/50): loss logLikelihood=128797.6088492589
# Logistic Regression (50/50): loss logLikelihood=128853.40252647224
# Logistic Regression (50/50): loss logLikelihood=128872.49332099913
# Logistic Regression (50/50): loss logLikelihood=128872.48896462568
# Logistic Regression (50/50): loss logLikelihood=128872.2047674102
# Logistic Regression (50/50): loss logLikelihood=128871.98487373808
# Logistic Regression (50/50): loss logLikelihood=128826.88052119562
# -------------------------------------------------
# Feature chosen:  PRI_lep_pt (index : 16 )
# Logistic Regression (50/50): loss logLikelihood=127203.14208020794
# Logistic Regression (50/50): loss logLikelihood=127177.08330437013
# Logistic Regression (50/50): loss logLikelihood=127177.7871615017
# Logistic Regression (50/50): loss logLikelihood=127174.45935585354
# Logistic Regression (50/50): loss logLikelihood=127058.4215992881
# Logistic Regression (50/50): loss logLikelihood=127170.67713816032
# Logistic Regression (50/50): loss logLikelihood=125940.06945329739
# Logistic Regression (50/50): loss logLikelihood=127175.58256482372
# Logistic Regression (50/50): loss logLikelihood=127175.29924077584
# Logistic Regression (50/50): loss logLikelihood=127175.7397497718
# Logistic Regression (50/50): loss logLikelihood=127174.37244096345
# Logistic Regression (50/50): loss logLikelihood=127175.88534923803
# Logistic Regression (50/50): loss logLikelihood=127095.21356220123
# Logistic Regression (50/50): loss logLikelihood=127129.69827308746
# Logistic Regression (50/50): loss logLikelihood=126904.09018942493
# Logistic Regression (50/50): loss logLikelihood=127175.95728985332
# Logistic Regression (50/50): loss logLikelihood=127176.02047206611
# Logistic Regression (50/50): loss logLikelihood=127175.87686523511
# Logistic Regression (50/50): loss logLikelihood=127175.48160145606
# Logistic Regression (50/50): loss logLikelihood=127167.57331437507
# -------------------------------------------------
# Feature chosen:  PRI_jet_leading_pt (index : 23 )
# Logistic Regression (50/50): loss logLikelihood=126937.01905125624
# Logistic Regression (50/50): loss logLikelihood=126881.2068674156
# Logistic Regression (50/50): loss logLikelihood=126900.81014218266
# Logistic Regression (50/50): loss logLikelihood=126888.39137086231
# Logistic Regression (50/50): loss logLikelihood=126772.64129640126
# Logistic Regression (50/50): loss logLikelihood=126903.43171535451
# Logistic Regression (50/50): loss logLikelihood=125683.76371033267
# Logistic Regression (50/50): loss logLikelihood=126903.10782356648
# Logistic Regression (50/50): loss logLikelihood=126902.79740427864
# Logistic Regression (50/50): loss logLikelihood=126903.16396120074
# Logistic Regression (50/50): loss logLikelihood=126901.95270501223
# Logistic Regression (50/50): loss logLikelihood=126903.42639159791
# Logistic Regression (50/50): loss logLikelihood=126852.83230723464
# Logistic Regression (50/50): loss logLikelihood=126897.47349086287
# Logistic Regression (50/50): loss logLikelihood=126903.65334907568
# Logistic Regression (50/50): loss logLikelihood=126903.71462330983
# Logistic Regression (50/50): loss logLikelihood=126903.49771463263
# Logistic Regression (50/50): loss logLikelihood=126903.12443831546
# Logistic Regression (50/50): loss logLikelihood=126901.10379853695
# -------------------------------------------------
# Feature chosen:  DER_pt_tot (index : 8 )
# Logistic Regression (50/50): loss logLikelihood=126806.27014595593
# Logistic Regression (50/50): loss logLikelihood=126729.75881025307
# Logistic Regression (50/50): loss logLikelihood=126769.6320586051
# Logistic Regression (50/50): loss logLikelihood=126757.45363038362
# Logistic Regression (50/50): loss logLikelihood=126760.83844025049
# Logistic Regression (50/50): loss logLikelihood=125560.89131242817
# Logistic Regression (50/50): loss logLikelihood=126771.74975378468
# Logistic Regression (50/50): loss logLikelihood=126771.42624814896
# Logistic Regression (50/50): loss logLikelihood=126771.836081904
# Logistic Regression (50/50): loss logLikelihood=126770.68118988424
# Logistic Regression (50/50): loss logLikelihood=126772.04000186455
# Logistic Regression (50/50): loss logLikelihood=126763.51683825659
# Logistic Regression (50/50): loss logLikelihood=126748.41513772812
# Logistic Regression (50/50): loss logLikelihood=126772.21347215144
# Logistic Regression (50/50): loss logLikelihood=126772.31638610821
# Logistic Regression (50/50): loss logLikelihood=126772.04916474137
# Logistic Regression (50/50): loss logLikelihood=126771.73884892983
# Logistic Regression (50/50): loss logLikelihood=126759.85430309546
# -------------------------------------------------
# Feature chosen:  DER_prodeta_jet_jet (index : 6 )
# Logistic Regression (50/50): loss logLikelihood=126791.54731077501
# Logistic Regression (50/50): loss logLikelihood=126714.5457724277
# Logistic Regression (50/50): loss logLikelihood=126767.3197308157
# Logistic Regression (50/50): loss logLikelihood=126746.20123095275
# Logistic Regression (50/50): loss logLikelihood=125545.93434310296
# Logistic Regression (50/50): loss logLikelihood=126756.65175267222
# Logistic Regression (50/50): loss logLikelihood=126756.34927431578
# Logistic Regression (50/50): loss logLikelihood=126756.71927746231
# Logistic Regression (50/50): loss logLikelihood=126755.55981497956
# Logistic Regression (50/50): loss logLikelihood=126756.94026205226
# Logistic Regression (50/50): loss logLikelihood=126748.70334716223
# Logistic Regression (50/50): loss logLikelihood=126734.17473367343
# Logistic Regression (50/50): loss logLikelihood=126757.16774363226
# Logistic Regression (50/50): loss logLikelihood=126757.24307095657
# Logistic Regression (50/50): loss logLikelihood=126757.23699605334
# Logistic Regression (50/50): loss logLikelihood=126756.7548566199
# Logistic Regression (50/50): loss logLikelihood=126745.58336818003
# -------------------------------------------------
# Feature chosen:  PRI_met_sumet (index : 21 )
# Logistic Regression (50/50): loss logLikelihood=126781.09544712632
# Logistic Regression (50/50): loss logLikelihood=126679.69260989381
# Logistic Regression (50/50): loss logLikelihood=126758.23479490446
# Logistic Regression (50/50): loss logLikelihood=126698.49663583151
# Logistic Regression (50/50): loss logLikelihood=125544.97072591688
# Logistic Regression (50/50): loss logLikelihood=126747.9953956099
# Logistic Regression (50/50): loss logLikelihood=126747.67253066048
# Logistic Regression (50/50): loss logLikelihood=126748.06977394313
# Logistic Regression (50/50): loss logLikelihood=126746.91992821936
# Logistic Regression (50/50): loss logLikelihood=126748.25062142829
# Logistic Regression (50/50): loss logLikelihood=126678.3402141526
# Logistic Regression (50/50): loss logLikelihood=126748.447668583
# Logistic Regression (50/50): loss logLikelihood=126748.53636386992
# Logistic Regression (50/50): loss logLikelihood=126748.5118275439
# Logistic Regression (50/50): loss logLikelihood=126748.04304613518
# Logistic Regression (50/50): loss logLikelihood=126701.03348677108
# -------------------------------------------------
# Feature chosen:  PRI_jet_num (index : 22 )
# Logistic Regression (50/50): loss logLikelihood=126710.35475605243
# Logistic Regression (50/50): loss logLikelihood=126632.62275179343
# Logistic Regression (50/50): loss logLikelihood=126682.82772888428
# Logistic Regression (50/50): loss logLikelihood=126681.32531696539
# Logistic Regression (50/50): loss logLikelihood=125432.08788556552
# Logistic Regression (50/50): loss logLikelihood=126677.70255776467
# Logistic Regression (50/50): loss logLikelihood=126677.42420756549
# Logistic Regression (50/50): loss logLikelihood=126677.77940249442
# Logistic Regression (50/50): loss logLikelihood=126676.72409274195
# Logistic Regression (50/50): loss logLikelihood=126677.94665472282
# Logistic Regression (50/50): loss logLikelihood=126678.09116208335
# Logistic Regression (50/50): loss logLikelihood=126678.20440322268
# Logistic Regression (50/50): loss logLikelihood=126678.1659602541
# Logistic Regression (50/50): loss logLikelihood=126677.72876292434
# Logistic Regression (50/50): loss logLikelihood=126685.39004613362
# -------------------------------------------------
# Feature chosen:  PRI_jet_all_pt (index : 29 )
# Logistic Regression (50/50): loss logLikelihood=126717.26668220412
# Logistic Regression (50/50): loss logLikelihood=126624.62642466198
# Logistic Regression (50/50): loss logLikelihood=126688.05395756854
# Logistic Regression (50/50): loss logLikelihood=126692.48579713274
# Logistic Regression (50/50): loss logLikelihood=125452.17895906088
# Logistic Regression (50/50): loss logLikelihood=126684.81207132759
# Logistic Regression (50/50): loss logLikelihood=126684.50269722586
# Logistic Regression (50/50): loss logLikelihood=126684.93668077362
# Logistic Regression (50/50): loss logLikelihood=126683.82383654836
# Logistic Regression (50/50): loss logLikelihood=126685.02734636907
# Logistic Regression (50/50): loss logLikelihood=126685.27747116855
# Logistic Regression (50/50): loss logLikelihood=126685.31079056734
# Logistic Regression (50/50): loss logLikelihood=126685.45204963132
# Logistic Regression (50/50): loss logLikelihood=126684.96470057403
# -------------------------------------------------
# Feature chosen:  DER_sum_pt (index : 9 )
# Logistic Regression (50/50): loss logLikelihood=126726.18910189052
# Logistic Regression (50/50): loss logLikelihood=135466.6432219919
# Logistic Regression (50/50): loss logLikelihood=126695.59509187724
# Logistic Regression (50/50): loss logLikelihood=125460.67720885413
# Logistic Regression (50/50): loss logLikelihood=126692.32819984957
# Logistic Regression (50/50): loss logLikelihood=126691.97651595969
# Logistic Regression (50/50): loss logLikelihood=126692.59928877588
# Logistic Regression (50/50): loss logLikelihood=126691.11083693054
# Logistic Regression (50/50): loss logLikelihood=126692.50177627672
# Logistic Regression (50/50): loss logLikelihood=126692.3152914185
# Logistic Regression (50/50): loss logLikelihood=126692.28639912629
# Logistic Regression (50/50): loss logLikelihood=126692.18111822875
# Logistic Regression (50/50): loss logLikelihood=126691.62248789685
# -------------------------------------------------
# Feature chosen:  DER_pt_h (index : 3 )
# Logistic Regression (50/50): loss logLikelihood=136536.5675199856
# Logistic Regression (50/50): loss logLikelihood=135920.6975191249
# Logistic Regression (50/50): loss logLikelihood=134977.9610159353
# Logistic Regression (50/50): loss logLikelihood=136467.73751884568
# Logistic Regression (50/50): loss logLikelihood=136466.60671499866
# Logistic Regression (50/50): loss logLikelihood=136461.2577544538
# Logistic Regression (50/50): loss logLikelihood=136477.35773662725
# Logistic Regression (50/50): loss logLikelihood=136465.78303735255
# Logistic Regression (50/50): loss logLikelihood=136658.60228796615
# Logistic Regression (50/50): loss logLikelihood=136665.98546448498
# Logistic Regression (50/50): loss logLikelihood=135709.4029401141
# Logistic Regression (50/50): loss logLikelihood=135765.88074469398
# -------------------------------------------------
# Feature chosen:  PRI_jet_leading_phi (index : 25 )
# Logistic Regression (50/50): loss logLikelihood=136522.60063771828
# Logistic Regression (50/50): loss logLikelihood=136223.13674481292
# Logistic Regression (50/50): loss logLikelihood=134955.45665565896
# Logistic Regression (50/50): loss logLikelihood=136454.1967369799
# Logistic Regression (50/50): loss logLikelihood=136452.81798485955
# Logistic Regression (50/50): loss logLikelihood=136449.34380407652
# Logistic Regression (50/50): loss logLikelihood=136467.3023549165
# Logistic Regression (50/50): loss logLikelihood=136465.40312505094
# Logistic Regression (50/50): loss logLikelihood=136560.7496156067
# Logistic Regression (50/50): loss logLikelihood=136616.67712217968
# Logistic Regression (50/50): loss logLikelihood=136633.70299747214

# %%
results_r2_stepwise(best_R2adj[:len(best_R2adj)-1], idx_features)
# Out:
# R2 asjusted values:
# 0.0451504623705
# 0.0837071436009
# 0.1114502216
# 0.129515591374
# 0.144709052712
# 0.150620360572
# 0.167785920059
# 0.173736708984
# 0.180550437114
# 0.186355079493
# 0.189306818965
# 0.192402228439
# 0.19350073574
# 0.194062713584
# 0.19537248148
# 0.196466838051
# 0.197308523439
# 0.199748798541
# 0.325906574739
# -------------------------------------------------------
# Number of features chosen: 19
#
#
# Indices of features chosen:  [13, 5, 1, 12, 11, 7, 2, 19, 26, 16, 23, 8, 6, 21, 22, 29, 9, 3, 25]
